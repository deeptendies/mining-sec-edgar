# %% [markdown]
# [sec official endpoints](https://www.sec.gov/developer)
#
# [sec edgar](https://www.sec.gov/edgar/)
#
# [python tool](https://sec-edgar.github.io/sec-edgar/)

# %% [markdown]
# # Ingest Data

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from secedgar.filings import Filing, FilingType

# 10Q filings for Apple (ticker "aapl")
from secedgar.filings import Filing, FilingType

my_filings = Filing(cik_lookup=['gme'],
                    filing_type=FilingType.FILING_10K,
                    count=1326380,
                   user_agent='deeptendies')

my_filings.save('filings')
# Out:
# /usr/lib/python3.8/threading.py:225: RuntimeWarning: coroutine 'NetworkClient.wait_for_download_async' was never awaited
#   self._lock = lock
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /home/stan/github-02/secedgar-eval/venv/lib/python3.8/site-packages/secedgar/filings/filing.py:182: UserWarning: Only 24 of 1326380 filings were found for 1326380.
#   warnings.warn("Only {num} of {count} filings were found for {cik}.".format(
# 30it [00:03,  8.68it/s]

# %% [markdown]
# # Parse Data

# %%
import glob
from secedgar.parser import MetaParser
from pathlib import Path

out_dir='parsed_filings'
Path(out_dir).mkdir(parents=True, exist_ok=True)

directory='filings'
for filepath in glob.iglob('filings/*/*/*.txt'):
    print(filepath)
    parser=MetaParser()
    parser.process(infile=filepath, out_dir=out_dir, create_subdir=True, rm_infile = False)
# Out:
# filings/gme/10-k/0001326380-17-000046.txt
# Warning: Trailing garbage
# filings/gme/10-k/0001326380-20-000022.txt
# Warning: Trailing garbage
# filings/gme/10-k/0000950123-11-030842.txt
# Warning: Trailing garbage
# filings/gme/10-k/0001326380-18-000033.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0000950134-09-006730.txt
# filings/gme/10-k/0001326380-16-000323.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0001193125-12-134615.txt
# Warning: Trailing garbage
# filings/gme/10-k/0001326380-19-000052.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0001445305-14-001259.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0001326380-16-000320.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0000950123-10-030164.txt
# Warning: Trailing garbage
# filings/gme/10-k/0000950134-06-006576.txt
# filings/gme/10-k/0001193125-13-140443.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0000950134-07-007555.txt
# filings/gme/10-k/0000950134-08-005892.txt
# filings/gme/10-k/0001326380-21-000032.txt
# Warning: Trailing garbage
# Warning: Trailing garbage
# Warning: Trailing garbage
# filings/gme/10-k/0001326380-15-000078.txt
# Warning: Trailing garbage
# Warning: Trailing garbage

# %% [markdown]
# # Extract Data
# extra data from a specific report type, and put them in a result list

# %% [markdown]
# After parsing, the parsed data will be created at `out_dir='parsed_filings'`
# need to access the file like so:

# %%
import json
import os
# os.walk(out_dir)
results = []
filings=[x[0] for x in os.walk(out_dir)]
for i in filings:
    meta=os.path.join(i, '*metadata.json')
    for filepath in glob.iglob(meta):
        print(filepath)
        with open(filepath) as file:
            data = json.load(file)
            for doc in data['documents']:
                if doc['type'] == '10-K':
                    print (doc['filename'])
                    filepaths2 = os.path.join(i, '*'+doc['filename'])
                    for filepath2 in glob.iglob(filepaths2):
                        with open(filepath2, 'r') as file2:
                            print (file2)
                            result = file2.read()
                            results.append(result)
# Out:
# parsed_filings/0001326380-21-000032/0.metadata.json
# gme-20210130.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-21-000032/0.gme-20210130.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0000950134-06-006576/0.metadata.json
# d34677e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950134-06-006576/0.d34677e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001193125-12-134615/0.metadata.json
# d283661d10k.htm
# <_io.TextIOWrapper name='parsed_filings/0001193125-12-134615/0.d283661d10k.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-16-000323/0.metadata.json
# parsed_filings/0000950134-09-006730/0.metadata.json
# d66430e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950134-09-006730/0.d66430e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0000950134-08-005892/0.metadata.json
# d55358e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950134-08-005892/0.d55358e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-17-000046/0.metadata.json
# a10k-fy16q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-17-000046/0.a10k-fy16q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0000950134-07-007555/0.metadata.json
# d45113e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950134-07-007555/0.d45113e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-16-000320/0.metadata.json
# a10k-fy15q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-16-000320/0.a10k-fy15q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001193125-13-140443/0.metadata.json
# d469015d10k.htm
# <_io.TextIOWrapper name='parsed_filings/0001193125-13-140443/0.d469015d10k.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-18-000033/0.metadata.json
# a10k-fy17q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-18-000033/0.a10k-fy17q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-20-000022/0.metadata.json
# a10k-fy19q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-20-000022/0.a10k-fy19q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001445305-14-001259/0.metadata.json
# a10k-fy13q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001445305-14-001259/0.a10k-fy13q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0000950123-10-030164/0.metadata.json
# d70778e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950123-10-030164/0.d70778e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0000950123-11-030842/0.metadata.json
# d80233e10vk.htm
# <_io.TextIOWrapper name='parsed_filings/0000950123-11-030842/0.d80233e10vk.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-19-000052/0.metadata.json
# a10k-fy18q4.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-19-000052/0.a10k-fy18q4.htm' mode='r' encoding='UTF-8'>
# parsed_filings/0001326380-15-000078/0.metadata.json
# form10k-fy14.htm
# <_io.TextIOWrapper name='parsed_filings/0001326380-15-000078/0.form10k-fy14.htm' mode='r' encoding='UTF-8'>

# %% [markdown]
# # What's left to do?
# Scrape & mine data
#
# with the above code, all the 10-k filing reports's html are stored in the result list, use beautiful soup & data scraping techniques to extra the business information you're interested in.
#
# resources:
# https://realpython.com/beautiful-soup-web-scraper-python/

# %%
result
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n\t<head>\n\t\t<!-- Document created using Wdesk 1 -->\n\t\t<!-- Copyright 2015 Workiva -->\n\t\t<title>10K - FY14Q4</title>\n\t</head>\n\t<body style="font-family:Times New Roman;font-size:10pt;">\n<a name="s4085CAA97E3A9C4C8316D0454E712E04"></a><div><div style="line-height:120%;text-align:left;font-size:10pt;"><a style="font-family:inherit;font-size:10pt;color:#0000ff;font-weight:bold;text-decoration:underline;" href="#sDC210064AB83C980266CD0455D2BAC68"><font style="font-family:inherit;font-size:10pt;color:#0000ff;font-weight:bold;text-decoration:underline;">Table of Contents</font></a></div></div><br><div style="line-height:120%;text-align:center;font-size:14pt;"><font style="font-family:inherit;font-size:14pt;font-weight:bold;">UNITED STATES SECURITIES AND EXCHANGE COMMISSION</font></div><div style="line-height:120%;text-align:center;font-size:12pt;"><font style="font-family:inherit;font-size:12pt;font-weight:bold;">Washington,&#160;D.C. 20549</font></div><div style="line-height:120%;padding-top:5px;text-align:center;font-size:18pt;"><font style="font-family:inherit;font-size:10pt;">&#160;</font><font style="font-family:inherit;font-size:18pt;font-weight:bold;">Form&#160;10-K</font></div><div style="line-height:120%;font-size:12pt;"><div style="padding-left:0px;text-indent:0px;line-height:normal;padding-top:10px;"><table cellpadding="0" cellspacing="0" style="font-family:Times New Roman;font-size:10pt;width:100%;border-collapse:collapse;text-align:left;"><tr><td colspan="2"></td></tr><tr><td width="12%"></td><td width="88%"></td></tr><tr><td style="vertical-align:top;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:12pt;"><font style="font-family:Wingdings;font-size:12pt;">&#254;</font></div></td><td style="vertical-align:top;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:12pt;"><font style="font-family:inherit;font-size:12pt;font-weight:bold;">ANNUAL REPORT PURSUANT TO SECTION&#160;13 OR 15(d) </font></div><div style="text-align:left;font-size:12pt;"><font style="font-family:inherit;font-size:12pt;font-weight:bold;">OF THE SECURITIES EXCHANGE ACT OF 1934</font></div></td></tr></table></div></div><div style="line-height:120%;padding-top:6px;text-indent:81px;font-size:10pt;"><font style="font-family:inherit;font-size:10pt;font-weight:bold;">For the fiscal year ended </font><font style="font-family:inherit;font-size:10pt;font-weight:bold;">January&#160;31, 2015</font><font style="font-family:inherit;font-size:10pt;font-weight:bold;">&#32;</font></div><div style="line-height:120%;padding-top:6px;text-align:center;font-size:10pt;"><font style="font-family:inherit;font-size:10pt;font-weight:bold;">OR</font></div><div style="line-height:120%;font-size:12pt;"><div style="padding-left:0px;text-indent:0px;line-height:normal;padding-top:10px;"><table cellpadding="0" cellspacing="0" style="font-family:Times New Roman;font-size:10pt;width:100%;border-collapse:collapse;text-align:left;"><tr><td colspan="2"></td></tr><tr><td width="12%"></td><td width="88%"></td></tr><tr><td style="vertical-align:top;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:10pt;"><font style="font-family:Wingdings;font-size:10pt;">&#168;</font></div></td><td style="vertical-align:top;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:12pt;"><font style="font-family:inherit;font-size:12pt;font-weight:bold;">TRANSITION REPORT PURSUANT TO SECTION&#160;13 OR 15(d)</font></div><div style="text-align:left;font-size:12pt;"><font style="font-family:inherit;font-size:12pt;font-weight:bold;">OF THE SECURITIES EXCHANGE ACT OF 1934</font></div></td></tr></table></div></div><div style="line-height:120%;padding-top:6px;text-a ...
